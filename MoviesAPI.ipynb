# %%
import numpy as np
import pandas as pd
import requests
import json

# %%
url1 = ("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1")

# %%
r = requests.get(url1)
x=r.json()

# %%
x.keys()
# Out:
# dict_keys(['page', 'total_results', 'total_pages', 'results'])

# %%
df1 = pd.DataFrame(x['results'])

# %%
df1
# Out:
#     adult                     backdrop_path              genre_ids      id  \
# 0   False  /mMaxGuQKuH4WUHBwUNhJOetDYE9.jpg        [35, 18, 10749]   19404
# 1   False  /j9XKiZrVeViAixVRzCta7h1VU9W.jpg               [80, 18]     278
# 2   False   /TU9NIjwzjoKPwQHoHshkFcQUCG.jpg           [35, 18, 53]  496243
# 3   False  /6xKCYgH16UuwEGAyroLU6p8HLIn.jpg               [80, 18]     238
# 4   False  /nvsdKYPKwf51EAgC0xLJMB9kUZM.jpg        [16, 18, 10749]  372058
# 5   False  /cTNYRUTXkBgPH3wP3kmPUB5U6dA.jpg        [18, 36, 10752]     424
# 6   False  /gLbBRyS7MBrmVUNce91Hmx9vzqI.jpg               [80, 18]     240
# 7   False  /mnpRKVSXBX6jb56nabvmGKA0Wig.jpg        [16, 14, 10751]     129
# 8   False   /Rlt20sEbOQKPVjia7lUilFm49W.jpg           [14, 18, 80]     497
# 9   False  /bORe0eI72D874TMawOOFvqWS6Xe.jpg               [35, 18]     637
# 10  False  /4cDFJr4HnXN5AdPw4AKrmLlMWdO.jpg               [80, 53]     680
# 11  False  /uUiId6cG32JSRI6RyBQSvQtLjz2.jpg  [28, 12, 16, 35, 878]  324857
# 12  False  /hqkIcbrOHL86UncnHIsHVcVmzue.jpg       [28, 80, 18, 53]     155
# 13  False  /wMgbnUVS9wbRGAdki8fqxKU1O0N.jpg        [35, 18, 10749]      13
# 14  False  /mMZRKb3NVo5ZeSPEIaNW9buLWQ0.jpg                   [18]     550
# 15  False  /8BPZO0Bf8TeAy8znF43z8soK3ys.jpg           [12, 14, 28]     122
# 16  False  /3md49VBCeqY6MSNyAVY6d5eC6bA.jpg           [18, 27, 53]     539
# 17  False  /pz9fxHyGiiNLZ21bccAtwrMAH7f.jpg           [28, 18, 36]   14537
# 18  False  /xGC2fY5KFmtuXnsuQwYQKFOLZFy.jpg                   [37]     429
# 19  False  /lH2Ga8OzjU1XlxJ73shOlPx6cRw.jpg                   [18]     389
#
#    original_language                                 original_title  \
# 0                 hi                   दिलवाले दुल्हनिया ले जायेंगे
# 1                 en                       The Shawshank Redemption
# 2                 ko                                            기생충
# 3                 en                                  The Godfather
# 4                 ja                                          君の名は。
# 5                 en                               Schindler's List
# 6                 en                         The Godfather: Part II
# 7                 ja                                       千と千尋の神隠し
# 8                 en                                 The Green Mile
# 9                 it                                La vita è bella
# 10                en                                   Pulp Fiction
# 11                en              Spider-Man: Into the Spider-Verse
# 12                en                                The Dark Knight
# 13                en                                   Forrest Gump
# 14                en                                     Fight Club
# 15                en  The Lord of the Rings: The Return of the King
# 16                en                                         Psycho
# 17                ja                                             切腹
# 18                it                Il buono, il brutto, il cattivo
# 19                en                                   12 Angry Men
#
#                                              overview  popularity  \
# 0   Raj is a rich, carefree, happy-go-lucky second...      14.599
# 1   Framed in the 1940s for the double murder of h...      32.041
# 2   All unemployed, Ki-taek's family takes peculia...      44.405
# 3   Spanning the years 1945 to 1955, a chronicle o...      29.314
# 4   High schoolers Mitsuha and Taki are complete s...      28.280
# 5   The true story of how businessman Oskar Schind...      23.171
# 6   In the continuing saga of the Corleone crime f...      24.222
# 7   A young girl, Chihiro, becomes trapped in a st...      33.291
# 8   A supernatural tale set on death row in a Sout...      21.664
# 9   A touching story of an Italian book seller of ...      12.904
# 10  A burger-loving hit man, his philosophical par...      37.512
# 11  Miles Morales is juggling his life between bei...      52.232
# 12  Batman raises the stakes in his war on crime. ...      32.881
# 13  A man with a low IQ has accomplished great thi...      25.345
# 14  A ticking-time-bomb insomniac and a slippery s...      53.656
# 15  Aragorn is revealed as the heir to the ancient...      38.139
# 16  When larcenous real estate clerk Marion Crane ...      18.660
# 17  Aging samurai Hanshiro Tsugumo arrives at the ...       8.766
# 18  While the Civil War rages between the Union an...      20.898
# 19  The defense and the prosecution have rested an...      14.204
#
#                          poster_path release_date  \
# 0   /uC6TTUhPpQCmgldGyYveKRAu8JN.jpg   1995-10-20
# 1   /9O7gLzmreU0nGkIB6K3BsJbzvNv.jpg   1994-09-23
# 2   /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg   2019-10-11
# 3   /rPdtLWNsZmAtoZl9PK7S2wE3qiS.jpg   1972-03-15
# 4   /xq1Ugd62d23K2knRUx6xxuALTZB.jpg   2017-04-07
# 5    /yPisjyLweCl1tbgwgtzBCNCBle.jpg   1993-12-15
# 6   /bVq65huQ8vHDd1a4Z37QtuyEvpA.jpg   1974-12-20
# 7   /oRvMaJOmapypFUcQqpgHMZA6qL9.jpg   2002-09-20
# 8   /sOHqdY1RnSn6kcfAHKu28jvTebE.jpg   1999-12-10
# 9   /f7DImXDebOs148U4uPjI61iDvaK.jpg   1998-10-22
# 10   /dM2w364MScsjFf8pfMbaWUcWrR.jpg   1994-10-14
# 11  /iiZZdoQBEYBv6id8su7ImL0oCbD.jpg   2018-12-14
# 12  /qJ2tW6WMUDux911r6m7haRef0WH.jpg   2008-07-18
# 13  /yE5d3BUhE8hCnkMUJOo1QDoOGNz.jpg   1994-07-06
# 14  /adw6Lq9FiC9zjYEpOqfq03ituwp.jpg   1999-10-15
# 15  /rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg   2003-12-17
# 16  /81d8oyEFgj7FlxJqSDXWr8JH8kV.jpg   1960-09-08
# 17  /5konZnIbcAxZjP616Cz5o9bKEfW.jpg   1963-09-11
# 18  /wfPHdfofBD5PN96dV96a51B3Ja2.jpg   1967-12-29
# 19  /3W0v956XxSG5xgm7LB6qu8ExYJ2.jpg   1957-04-10
#
#                                             title  video  vote_average  \
# 0                     Dilwale Dulhania Le Jayenge  False           8.9
# 1                        The Shawshank Redemption  False           8.7
# 2                                        Parasite  False           8.7
# 3                                   The Godfather  False           8.6
# 4                                      Your Name.  False           8.6
# 5                                Schindler's List  False           8.5
# 6                          The Godfather: Part II  False           8.5
# 7                                   Spirited Away  False           8.5
# 8                                  The Green Mile  False           8.5
# 9                               Life Is Beautiful  False           8.5
# 10                                   Pulp Fiction  False           8.4
# 11              Spider-Man: Into the Spider-Verse  False           8.4
# 12                                The Dark Knight  False           8.4
# 13                                   Forrest Gump  False           8.4
# 14                                     Fight Club  False           8.4
# 15  The Lord of the Rings: The Return of the King  False           8.4
# 16                                         Psycho  False           8.4
# 17                                       Harakiri  False           8.4
# 18                 The Good, the Bad and the Ugly  False           8.4
# 19                                   12 Angry Men  False           8.4
#
#     vote_count
# 0         2099
# 1        13656
# 2          535
# 3        10446
# 4         4432
# 5         8388
# 6         6142
# 7         7739
# 8         8662
# 9         7527
# 10       15888
# 11        4861
# 12       19481
# 13       15507
# 14       16876
# 15       13649
# 16        5185
# 17         268
# 18        4214
# 19        3917

# %%
df1.columns
# Out:
# Index(['adult', 'backdrop_path', 'genre_ids', 'id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
df1.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)

# %%
df1
# Out:
#         id                                           overview  popularity  \
# 0    19404  Raj is a rich, carefree, happy-go-lucky second...      14.599
# 1      278  Framed in the 1940s for the double murder of h...      32.041
# 2   496243  All unemployed, Ki-taek's family takes peculia...      44.405
# 3      238  Spanning the years 1945 to 1955, a chronicle o...      29.314
# 4   372058  High schoolers Mitsuha and Taki are complete s...      28.280
# 5      424  The true story of how businessman Oskar Schind...      23.171
# 6      240  In the continuing saga of the Corleone crime f...      24.222
# 7      129  A young girl, Chihiro, becomes trapped in a st...      33.291
# 8      497  A supernatural tale set on death row in a Sout...      21.664
# 9      637  A touching story of an Italian book seller of ...      12.904
# 10     680  A burger-loving hit man, his philosophical par...      37.512
# 11  324857  Miles Morales is juggling his life between bei...      52.232
# 12     155  Batman raises the stakes in his war on crime. ...      32.881
# 13      13  A man with a low IQ has accomplished great thi...      25.345
# 14     550  A ticking-time-bomb insomniac and a slippery s...      53.656
# 15     122  Aragorn is revealed as the heir to the ancient...      38.139
# 16     539  When larcenous real estate clerk Marion Crane ...      18.660
# 17   14537  Aging samurai Hanshiro Tsugumo arrives at the ...       8.766
# 18     429  While the Civil War rages between the Union an...      20.898
# 19     389  The defense and the prosecution have rested an...      14.204
#
#    release_date                                          title  vote_average
# 0    1995-10-20                    Dilwale Dulhania Le Jayenge           8.9
# 1    1994-09-23                       The Shawshank Redemption           8.7
# 2    2019-10-11                                       Parasite           8.7
# 3    1972-03-15                                  The Godfather           8.6
# 4    2017-04-07                                     Your Name.           8.6
# 5    1993-12-15                               Schindler's List           8.5
# 6    1974-12-20                         The Godfather: Part II           8.5
# 7    2002-09-20                                  Spirited Away           8.5
# 8    1999-12-10                                 The Green Mile           8.5
# 9    1998-10-22                              Life Is Beautiful           8.5
# 10   1994-10-14                                   Pulp Fiction           8.4
# 11   2018-12-14              Spider-Man: Into the Spider-Verse           8.4
# 12   2008-07-18                                The Dark Knight           8.4
# 13   1994-07-06                                   Forrest Gump           8.4
# 14   1999-10-15                                     Fight Club           8.4
# 15   2003-12-17  The Lord of the Rings: The Return of the King           8.4
# 16   1960-09-08                                         Psycho           8.4
# 17   1963-09-11                                       Harakiri           8.4
# 18   1967-12-29                 The Good, the Bad and the Ugly           8.4
# 19   1957-04-10                                   12 Angry Men           8.4

# %%
url2=("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=2")
r = requests.get(url2)
x=r.json()
df2 = pd.DataFrame(x['results'])
df2.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)
df2
# Out:
#         id                                           overview  popularity  \
# 0      769  The true story of Henry Hill, a half-Irish, ha...      21.425
# 1      311  A former Prohibition-era Jewish gangster retur...      16.816
# 2    11216  A filmmaker recalls his childhood, when he fel...      10.198
# 3      510  While serving time for insanity at a state men...      18.219
# 4      346  A samurai answers a village's request for prot...      14.835
# 5    40096  The lively João Grilo and the sly Chicó are po...       9.232
# 6      901  City Lights is the first silent film that Char...       9.400
# 7   244786  Under the direction of a ruthless instructor, ...      28.698
# 8    12477  In the final months of World War II, 14-year-o...       0.600
# 9      598  Cidade de Deus is a shantytown that started du...      13.969
# 10     599  A hack screenwriter writes a screenplay for a ...      10.785
# 11  432517  Long buried secrets finally come to light as s...      13.260
# 12   18491  The second of two theatrically released follow...      10.338
# 13     914  Dictator Adenoid Hynkel tries to expand his em...       7.942
# 14    4935  When Sophie, a shy young woman, is cursed with...      19.385
# 15  517814  Zain, a 12-year-old boy scrambling to survive ...      14.604
# 16      73  Derek Vineyard is paroled after serving 3 year...      17.196
# 17    3782  Mr. Watanabe suddenly finds that he has termin...       8.352
# 18  299534  After the devastating events of Avengers: Infi...     128.417
# 19   26451  A chief of detectives, homicide section, kills...      10.134
#
#    release_date                                           title  vote_average
# 0    1990-09-19                                      GoodFellas           8.4
# 1    1984-06-01                     Once Upon a Time in America           8.4
# 2    2002-06-14                                 Cinema Paradiso           8.4
# 3    1975-11-18                 One Flew Over the Cuckoo's Nest           8.4
# 4    1956-11-19                                   Seven Samurai           8.4
# 5    2000-09-15                                    A Dog's Will           8.4
# 6    1931-03-07                                     City Lights           8.4
# 7    2014-10-10                                        Whiplash           8.4
# 8    2019-01-01                          Grave of the Fireflies           8.4
# 9    2002-08-31                                     City of God           8.4
# 10   1950-08-10                                Sunset Boulevard           8.4
# 11   2017-01-15                     Sherlock: The Final Problem           8.4
# 12   1997-07-19  Neon Genesis Evangelion: The End of Evangelion           8.4
# 13   1940-10-15                              The Great Dictator           8.4
# 14   2005-06-10                            Howl's Moving Castle           8.4
# 15   2018-12-14                                       Capernaum           8.4
# 16   1998-10-30                              American History X           8.4
# 17   1956-03-25                                           Ikiru           8.4
# 18   2019-04-26                               Avengers: Endgame           8.4
# 19   1970-12-20      Investigation of a Citizen Above Suspicion           8.4

# %%
url3=("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=3")
r = requests.get(url3)
x=r.json()
df3 = pd.DataFrame(x['results'])
df3.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)
df3
# Out:
#         id                                           overview  popularity  \
# 0     1891  The epic saga continues as Luke Skywalker, in ...      23.029
# 1   313106  In 2013, something terrible is awakening in Lo...       7.398
# 2    11659  Spanning four decades, from the chaotic 1960s ...       5.633
# 3      128  Ashitaka, a prince of the disappearing Ainu tr...      16.709
# 4      207  At an elite, old-fashioned boarding school in ...      17.292
# 5    20914  Like in many other Monicelli movies, the main ...       7.943
# 6   265177  A peculiar neighbor offers hope to a recent wi...      10.454
# 7   290098  1930s Korea, in the period of Japanese occupat...      17.435
# 8    10376  The story of a virtuoso piano player who lives...       9.307
# 9      797  A young nurse, Alma, is put in charge of Elisa...       8.116
# 10     895  An expansive Russian drama, this film focuses ...       8.711
# 11     567  Professional photographer L.B. "Jeff" Jeffries...      13.545
# 12     975  During World War I, commanding officer General...       8.649
# 13   18148  The elderly Shukishi and his wife, Tomi, take ...      10.555
# 14     423  The true story of pianist Wladyslaw Szpilman's...      15.347
# 15  452522  An idiosyncratic FBI agent investigates the mu...      12.484
# 16     101  Léon, the top hit man in New York, has earned ...      27.117
# 17   37257  When Leonard Vole is arrested for the sensatio...      10.083
# 18   24382  Best friends Peppe and Mario are thieves, but ...       7.922
# 19     807  Two homicide detectives are on a desperate hun...      30.535
#
#    release_date                              title  vote_average
# 0    1980-05-21            The Empire Strikes Back           8.4
# 1    2013-11-23  Doctor Who: The Day of the Doctor           8.4
# 2    2003-08-30                  The Best of Youth           8.3
# 3    1999-10-29                  Princess Mononoke           8.3
# 4    1989-06-09                 Dead Poets Society           8.3
# 5    1975-08-15                         My Friends           8.3
# 6    2014-08-29                              Mommy           8.3
# 7    2016-10-21                     The Handmaiden           8.3
# 8    1998-10-28                 The Legend of 1900           8.3
# 9    1967-03-06                            Persona           8.3
# 10   1966-12-16                      Andrei Rublev           8.3
# 11   1954-08-04                        Rear Window           8.3
# 12   1957-12-25                     Paths of Glory           8.3
# 13   1972-03-13                        Tokyo Story           8.3
# 14   2002-12-04                        The Pianist           8.3
# 15   1989-12-31                         Twin Peaks           8.3
# 16   1994-11-18             Léon: The Professional           8.3
# 17   1957-12-17        Witness for the Prosecution           8.3
# 18   1958-06-06         Big Deal on Madonna Street           8.3
# 19   1995-09-22                              Se7en           8.3

# %%
url4=("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=4")
r = requests.get(url4)
x=r.json()
df4 = pd.DataFrame(x['results'])
df4.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)
df4
# Out:
#         id                                           overview  popularity  \
# 0      120  Young hobbit Frodo Baggins, after inheriting a...      40.247
# 1   490132  Tony Lip, a bouncer in 1962, is hired to drive...      30.006
# 2   398818  Elio Perlman is spending the summer with his f...      18.089
# 3    24188  Roberto, a shy law student in Rome, meets Brun...       6.118
# 4     3082  The Tramp struggles to live in modern industri...       8.587
# 5    27205  Cobb, a skilled thief who commits corporate es...      38.401
# 6      274  Clarice Starling is a top student at the FBI's...       4.241
# 7   299536  As the Avengers and their allies have continue...      81.555
# 8      121  Frodo and Sam are trekking to Mordor to destro...      29.672
# 9   378064  Shouya Ishida starts bullying the new girl in ...      17.747
# 10   12493  An executive of a shoe company becomes a victi...       9.209
# 11     335  A widow whose land and life are in danger as t...      16.416
# 12   25237  The invasion of a village in Byelorussia by Ge...       7.366
# 13  455661  A closeted boy runs the risk of being outed by...       5.530
# 14    1398  Near a gray and unnamed city is the Zone, a pl...      11.696
# 15  157336  Interstellar chronicles the adventures of a gr...      42.815
# 16  538362  The incredible true story behind the most cont...      10.796
# 17   10098  Considered one of Charlie Chaplin's best films...       7.903
# 18   77338  A true story of two men who should never have ...      15.212
# 19     105  Eighties teenager Marty McFly is accidentally ...      23.728
#
#    release_date                                              title  \
# 0    2001-12-19  The Lord of the Rings: The Fellowship of the Ring
# 1    2018-11-16                                         Green Book
# 2    2017-11-24                               Call Me by Your Name
# 3    1962-12-04                                        Il Sorpasso
# 4    1936-02-05                                       Modern Times
# 5    2010-07-16                                          Inception
# 6    1991-02-01                           The Silence of the Lambs
# 7    2018-04-27                             Avengers: Infinity War
# 8    2002-12-18              The Lord of the Rings: The Two Towers
# 9    2017-10-20                                     A Silent Voice
# 10   1963-11-26                                       High and Low
# 11   1969-05-28                       Once Upon a Time in the West
# 12   1985-12-06                                       Come and See
# 13   2017-06-01                                     In a Heartbeat
# 14   1979-08-01                                            Stalker
# 15   2014-11-05                                       Interstellar
# 16   2018-09-12                                         On My Skin
# 17   1921-02-06                                            The Kid
# 18   2011-11-02                                   The Intouchables
# 19   1985-07-03                                 Back to the Future
#
#     vote_average
# 0            8.3
# 1            8.3
# 2            8.3
# 3            8.3
# 4            8.3
# 5            8.3
# 6            8.3
# 7            8.3
# 8            8.3
# 9            8.3
# 10           8.3
# 11           8.3
# 12           8.3
# 13           8.3
# 14           8.3
# 15           8.2
# 16           8.2
# 17           8.2
# 18           8.2
# 19           8.2

# %%
url5=("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=5")
r = requests.get(url5)
x=r.json()
df5 = pd.DataFrame(x['results'])
df5.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)
df5
# Out:
#         id                                           overview  popularity  \
# 0     8587  A young lion cub named Simba can't wait to be ...      33.387
# 1   339877  The film brings the paintings of Vincent van G...      11.177
# 2   406997  The story of August Pullman – a boy with facia...      18.734
# 3      284  Bud Baxter is a minor clerk in a huge New York...      13.054
# 4       28  At the height of the Vietnam war, Captain Benj...      28.174
# 5     5156  Antonio, an unemployed man in the depressed po...       7.508
# 6      426  A retired San Francisco detective suffering fr...      13.625
# 7   470044  Raised in a poverty-stricken slum, a 16-year-o...      18.607
# 8      670  With no clue how he came to be imprisoned, dru...      15.480
# 9     1585  A holiday favourite for generations...  George...      12.120
# 10     422  Guido Anselmi, a film director, finds himself ...      11.904
# 11     490  When disillusioned Swedish knight Antonius Blo...       7.910
# 12     992  A film projectionist longs to be a detective, ...       7.201
# 13     629  Held in an L.A. interrogation room, Verbal Kin...      16.768
# 14  411088  A young businessman wakes up in a hotel room, ...      20.348
# 15   38288  The shorts of Aldo , Giovanni &amp; Giacomo wa...       6.148
# 16      19  In a futuristic city sharply divided between t...      13.055
# 17  110420  After her werewolf lover unexpectedly dies in ...      10.449
# 18     694  Jack Torrance accepts a caretaker job at the O...      22.107
# 19     705  From the moment she glimpses her idol at the s...      11.233
#
#    release_date                  title  vote_average
# 0    1994-06-23          The Lion King           8.2
# 1    2017-09-22         Loving Vincent           8.2
# 2    2017-11-17                 Wonder           8.2
# 3    1960-06-15          The Apartment           8.2
# 4    1979-08-15         Apocalypse Now           8.2
# 5    1949-12-12        Bicycle Thieves           8.2
# 6    1958-05-09                Vertigo           8.2
# 7    2018-10-19        The Hate U Give           8.2
# 8    2003-11-21                 Oldboy           8.2
# 9    1947-01-07  It's a Wonderful Life           8.2
# 10   1963-06-24                     8½           8.2
# 11   1958-10-13       The Seventh Seal           8.2
# 12   1924-04-21          Sherlock, Jr.           8.2
# 13   1995-08-16     The Usual Suspects           8.2
# 14   2016-09-22    The Invisible Guest           8.2
# 15   1996-01-01                I Corti           8.2
# 16   2010-04-25             Metropolis           8.2
# 17   2013-11-26          Wolf Children           8.2
# 18   1980-05-23            The Shining           8.2
# 19   2000-10-06          All About Eve           8.2

# %%
url6=("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=6")
r = requests.get(url6)
x=r.json()
df6 = pd.DataFrame(x['results'])
df6.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)
df6
# Out:
#         id                                           overview  popularity  \
# 0       77  Leonard Shelby is tracking down the man who ra...      15.286
# 1       11  Princess Leia is captured and held hostage by ...      44.196
# 2      185  In a near-future Britain, young Alexander DeLa...      16.851
# 3      239  Two musicians witness a mob hit and struggle t...      11.214
# 4      996  A rich woman and a calculating insurance agent...       9.644
# 5      548  Brimming with action while incisively examinin...       8.782
# 6    19542  In this classic drama, Vicky Page is an aspiri...       7.723
# 7    92321  One hot summer day a little girl gets lost in ...       0.600
# 8   399106  A mother bird tries to teach her little one ho...       7.632
# 9    10494  A retired pop singer turned actress' sense of ...      11.165
# 10     103  A mentally unstable Vietnam War veteran works ...      17.655
# 11  354912  Despite his family’s baffling generations-old ...      23.976
# 12     780  A classic of the silent age, this film tells t...       8.942
# 13  359940  After seven months have passed without a culpr...      16.972
# 14    1124  A mysterious story of two magicians whose inte...      25.290
# 15  334543  A five-year-old Indian boy gets lost on the st...      22.813
# 16     500  A botched robbery indicates a police informant...      22.218
# 17  527641  Seventeen-year-old Stella spends most of her t...      23.743
# 18     935  After the insane General Jack D. Ripper initia...      12.283
# 19  449176  Everyone deserves a great love story. But for ...      17.362
#
#    release_date                                              title  \
# 0    2001-03-16                                            Memento
# 1    1977-05-25                                          Star Wars
# 2    1971-12-18                                 A Clockwork Orange
# 3    1959-03-18                                   Some Like It Hot
# 4    1944-04-24                                   Double Indemnity
# 5    1950-12-26                                           Rashomon
# 6    1948-09-06                                      The Red Shoes
# 7    2012-06-30                                 Hotarubi no Mori e
# 8    2016-06-17                                              Piper
# 9    1999-08-20                                       Perfect Blue
# 10   1976-02-08                                        Taxi Driver
# 11   2017-11-22                                               Coco
# 12   1929-03-28                         The Passion of Joan of Arc
# 13   2017-11-10          Three Billboards Outside Ebbing, Missouri
# 14   2006-10-19                                       The Prestige
# 15   2016-11-25                                               Lion
# 16   1992-10-23                                     Reservoir Dogs
# 17   2019-03-15                                    Five Feet Apart
# 18   1964-01-29  Dr. Strangelove or: How I Learned to Stop Worr...
# 19   2018-03-16                                        Love, Simon
#
#     vote_average
# 0            8.2
# 1            8.2
# 2            8.2
# 3            8.2
# 4            8.2
# 5            8.2
# 6            8.2
# 7            8.2
# 8            8.2
# 9            8.2
# 10           8.2
# 11           8.2
# 12           8.1
# 13           8.2
# 14           8.2
# 15           8.2
# 16           8.2
# 17           8.1
# 18           8.1
# 19           8.1

# %%
url7=("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=7")
r = requests.get(url7)
x=r.json()
df7 = pd.DataFrame(x['results'])
df7.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)
df7
# Out:
#         id                                           overview  popularity  \
# 0    11878  A nameless ronin, or samurai with no master, e...       8.583
# 1      833  When elderly pensioner Umberto Domenico Ferrar...       5.922
# 2    28978  Charlie, a wandering tramp, becomes a circus h...       7.518
# 3     8392  Two sisters move to the country with their fat...      29.281
# 4    50014  Aibileen Clark is a middle-aged African-Americ...       9.411
# 5      832  In this classic German thriller, Hans Beckert,...       7.835
# 6      872  In 1927 Hollywood, a silent film production co...      10.940
# 7      961  During America’s Civil War Union spies steal e...       9.329
# 8      654  Terry Malloy dreams about being a prize fighte...      11.495
# 9     1396  A dying man in his forties recalls his childho...       8.762
# 10   16869  In Nazi-occupied France during World War II, a...      24.948
# 11     655  A man wanders out of the desert not knowing wh...       8.158
# 12     614  Crotchety retired doctor Isak Borg travels fro...       9.343
# 13    1422  To take down South Boston's Irish Mafia, the p...      20.762
# 14  264644  Jack is a young boy of 5 years old who has liv...      13.726
# 15     307  ROME, OPEN CITY is a landmark in film history....       7.270
# 16      98  In the year 180, the death of emperor Marcus A...      22.618
# 17  110416  The story of the last Seal Child’s journey hom...       8.313
# 18     111  After getting a green card in exchange for ass...      15.797
# 19     439  Episodic journey of an Italian journalist scou...       8.378
#
#    release_date                 title  vote_average
# 0    1961-09-13               Yojimbo           8.1
# 1    1952-11-07            Umberto D.           8.1
# 2    1928-01-06            The Circus           8.1
# 3    2018-12-11    My Neighbor Totoro           8.1
# 4    2011-08-10              The Help           8.1
# 5    1933-05-14                     M           8.1
# 6    1952-04-10   Singin' in the Rain           8.1
# 7    1927-01-15           The General           8.1
# 8    1954-07-28     On the Waterfront           8.1
# 9    1975-11-11                Mirror           8.1
# 10   2009-08-21  Inglourious Basterds           8.1
# 11   1984-11-02          Paris, Texas           8.1
# 12   1957-12-26     Wild Strawberries           8.1
# 13   2006-10-05          The Departed           8.1
# 14   2015-10-16                  Room           8.1
# 15   1946-02-25       Rome, Open City           8.1
# 16   2000-05-01             Gladiator           8.1
# 17   2014-12-19       Song of the Sea           8.1
# 18   1983-12-08              Scarface           8.1
# 19   1961-04-19         La Dolce Vita           8.1

# %%
url8=("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=8")
r = requests.get(url8)
x=r.json()
df8 = pd.DataFrame(x['results'])
df8.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)
df8

# %%
url9=("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=9")
r = requests.get(url9)
x=r.json()
df9 = pd.DataFrame(x['results'])
df9.drop(['adult', 'backdrop_path', 'genre_ids', 'id', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)
df9
# Out:
#                                              overview  popularity  \
# 0   World War II soldier-turned-U.S. Marshal Teddy...      19.577
# 1   Dangal is an extraordinary true story based on...       7.345
# 2   A story about a mentally ill man wrongfully ac...       7.424
# 3   As U.S. troops storm the beaches of Normandy, ...      22.964
# 4   A pragmatic U.S. Marine observes the dehumaniz...      16.823
# 5   Will Hunting has a genius-level IQ but chooses...      12.462
# 6                                                           6.645
# 7   Harry, Ron and Hermione continue their quest t...      34.691
# 8   A night at the movies turns into a nightmare w...       8.723
# 9   Taking place in Hong Kong of 1962, a melanchol...      13.278
# 10  Set in the 22nd century, The Matrix tells the ...      37.544
# 11  WWII American Army Medic Desmond T. Doss, who ...      20.941
# 12  Toshiro Mifune swaggers and snarls to brillian...       6.430
# 13  Ruthless silver miner, turned oil prospector, ...      11.068
# 14  Two melancholic Hong Kong policemen fall in lo...      11.219
# 15  The film is about an unemployed banker, Henri ...       7.083
# 16  A mother's last wishes send twins Jeanne and S...       7.767
# 17  1986 Gyunggi Province. The body of a young wom...      11.650
# 18  Against all the odds, a thirteen year old boy ...       7.758
# 19  Based on actual events that took place at Gwan...       9.995
#
#    release_date                                         title  vote_average
# 0    2010-02-18                                Shutter Island           8.1
# 1    2016-12-21                                        Dangal           8.1
# 2    2013-01-23                         Miracle in Cell No. 7           8.1
# 3    1998-07-24                           Saving Private Ryan           8.1
# 4    1987-06-26                             Full Metal Jacket           8.1
# 5    1997-12-05                             Good Will Hunting           8.1
# 6    2018-12-27                           Minha Vida em Marte           8.1
# 7    2011-07-15  Harry Potter and the Deathly Hallows: Part 2           8.1
# 8    1983-11-14                    Michael Jackson's Thriller           8.1
# 9    2000-05-22                          In the Mood for Love           8.1
# 10   1999-03-30                                    The Matrix           8.1
# 11   2016-11-04                                 Hacksaw Ridge           8.1
# 12   1963-05-07                                       Sanjuro           8.1
# 13   2007-12-28                           There Will Be Blood           8.1
# 14   1994-09-15                             Chungking Express           8.1
# 15   1947-04-11                              Monsieur Verdoux           8.1
# 16   2010-09-04                                     Incendies           8.1
# 17   2003-04-24                            Memories of Murder           8.1
# 18   2019-03-01                The Boy Who Harnessed the Wind           8.1
# 19   2011-09-22                                      Silenced           8.1

# %%
url10=("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=10")
r = requests.get(url10)
x=r.json()
df10 = pd.DataFrame(x['results'])
df10.drop(['adult', 'backdrop_path', 'genre_ids', 'id', 'original_language', 'poster_path', 'original_title', 'video', 'vote_count'], axis=1, inplace=True)
df10
# Out:
#                                              overview  popularity  \
# 0   The Russian poet Andrei Gorchakov, accompanied...       7.582
# 1   Set in the 1930s this intricate caper deals wi...      12.121
# 2                                                           5.123
# 3   Based on the real life story of legendary cryp...      27.964
# 4   A tragic love story set in East Berlin with th...       9.524
# 5   In postwar Vienna, Austria, Holly Martins, a w...      10.737
# 6   During its return to the earth, commercial spa...      25.954
# 7   Joel Barish, heartbroken that his girlfriend u...      16.450
# 8   Newspaper magnate, Charles Foster Kane is take...      13.914
# 9   Rome, 1957. A woman, Cabiria, is robbed and le...       5.507
# 10  Japanese peasants Matashichi and Tahei try and...       8.136
# 11  A Victorian surgeon rescues a heavily disfigur...      10.444
# 12  After leaving her daughter Jessica in a small ...       9.055
# 13  An urban office worker finds that paper airpla...       6.578
# 14  Mr. Kim is jobless, lost in debt and has been ...       6.211
# 15  A German submarine hunts allied ships during t...      11.993
# 16  Singer Freddie Mercury, guitarist Brian May, d...      43.539
# 17  In the South American jungle, supplies of nitr...       9.394
# 18  Young Vincent Malloy dreams of being just like...       5.792
# 19  In 1947, four German judges who served on the ...       8.789
#
#    release_date                                  title  vote_average
# 0    1983-10-05                              Nostalgia           8.1
# 1    1973-12-25                              The Sting           8.1
# 2    2009-03-01                       Tel chi el telùn           8.1
# 3    2014-12-19                     The Imitation Game           8.1
# 4    2006-06-06                    The Lives of Others           8.1
# 5    1950-02-02                          The Third Man           8.1
# 6    1979-05-25                                  Alien           8.1
# 7    2004-03-19  Eternal Sunshine of the Spotless Mind           8.1
# 8    1941-05-01                           Citizen Kane           8.1
# 9    1957-12-31                      Nights of Cabiria           8.1
# 10   1958-12-28                    The Hidden Fortress           8.1
# 11   1980-10-03                       The Elephant Man           8.1
# 12   2015-08-28                      The Second Mother           8.1
# 13   2012-11-02                               Paperman           8.1
# 14   2010-02-05                   Castaway on the Moon           8.1
# 15   1982-02-10                               Das Boot           8.1
# 16   2018-11-02                      Bohemian Rhapsody           8.1
# 17   1955-02-16                      The Wages of Fear           8.1
# 18   1982-01-01                                Vincent           8.1
# 19   1961-12-19                  Judgment at Nuremberg           8.0

# %%
df=pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10])

# %%
df
# Out:
#                                              overview  popularity  \
# 0   Raj is a rich, carefree, happy-go-lucky second...      14.599
# 1   Framed in the 1940s for the double murder of h...      32.041
# 2   All unemployed, Ki-taek's family takes peculia...      44.405
# 3   Spanning the years 1945 to 1955, a chronicle o...      29.314
# 4   High schoolers Mitsuha and Taki are complete s...      28.280
# 5   The true story of how businessman Oskar Schind...      23.171
# 6   In the continuing saga of the Corleone crime f...      24.222
# 7   A young girl, Chihiro, becomes trapped in a st...      33.291
# 8   A supernatural tale set on death row in a Sout...      21.664
# 9   A touching story of an Italian book seller of ...      12.904
# 10  A burger-loving hit man, his philosophical par...      37.512
# 11  Miles Morales is juggling his life between bei...      52.232
# 12  Batman raises the stakes in his war on crime. ...      32.881
# 13  A man with a low IQ has accomplished great thi...      25.345
# 14  A ticking-time-bomb insomniac and a slippery s...      53.656
# 15  Aragorn is revealed as the heir to the ancient...      38.139
# 16  When larcenous real estate clerk Marion Crane ...      18.660
# 17  Aging samurai Hanshiro Tsugumo arrives at the ...       8.766
# 18  While the Civil War rages between the Union an...      20.898
# 19  The defense and the prosecution have rested an...      14.204
# 0   The true story of Henry Hill, a half-Irish, ha...      21.425
# 1   A former Prohibition-era Jewish gangster retur...      16.816
# 2   A filmmaker recalls his childhood, when he fel...      10.198
# 3   While serving time for insanity at a state men...      18.219
# 4   A samurai answers a village's request for prot...      14.835
# 5   The lively João Grilo and the sly Chicó are po...       9.232
# 6   City Lights is the first silent film that Char...       9.400
# 7   Under the direction of a ruthless instructor, ...      28.698
# 8   In the final months of World War II, 14-year-o...       0.600
# 9   Cidade de Deus is a shantytown that started du...      13.969
# ..                                                ...         ...
# 10  Set in the 22nd century, The Matrix tells the ...      37.544
# 11  WWII American Army Medic Desmond T. Doss, who ...      20.941
# 12  Toshiro Mifune swaggers and snarls to brillian...       6.430
# 13  Ruthless silver miner, turned oil prospector, ...      11.068
# 14  Two melancholic Hong Kong policemen fall in lo...      11.219
# 15  The film is about an unemployed banker, Henri ...       7.083
# 16  A mother's last wishes send twins Jeanne and S...       7.767
# 17  1986 Gyunggi Province. The body of a young wom...      11.650
# 18  Against all the odds, a thirteen year old boy ...       7.758
# 19  Based on actual events that took place at Gwan...       9.995
# 0   The Russian poet Andrei Gorchakov, accompanied...       7.582
# 1   Set in the 1930s this intricate caper deals wi...      12.121
# 2                                                           5.123
# 3   Based on the real life story of legendary cryp...      27.964
# 4   A tragic love story set in East Berlin with th...       9.524
# 5   In postwar Vienna, Austria, Holly Martins, a w...      10.737
# 6   During its return to the earth, commercial spa...      25.954
# 7   Joel Barish, heartbroken that his girlfriend u...      16.450
# 8   Newspaper magnate, Charles Foster Kane is take...      13.914
# 9   Rome, 1957. A woman, Cabiria, is robbed and le...       5.507
# 10  Japanese peasants Matashichi and Tahei try and...       8.136
# 11  A Victorian surgeon rescues a heavily disfigur...      10.444
# 12  After leaving her daughter Jessica in a small ...       9.055
# 13  An urban office worker finds that paper airpla...       6.578
# 14  Mr. Kim is jobless, lost in debt and has been ...       6.211
# 15  A German submarine hunts allied ships during t...      11.993
# 16  Singer Freddie Mercury, guitarist Brian May, d...      43.539
# 17  In the South American jungle, supplies of nitr...       9.394
# 18  Young Vincent Malloy dreams of being just like...       5.792
# 19  In 1947, four German judges who served on the ...       8.789
#
#    release_date                                          title  vote_average
# 0    1995-10-20                    Dilwale Dulhania Le Jayenge           8.9
# 1    1994-09-23                       The Shawshank Redemption           8.7
# 2    2019-10-11                                       Parasite           8.7
# 3    1972-03-15                                  The Godfather           8.6
# 4    2017-04-07                                     Your Name.           8.6
# 5    1993-12-15                               Schindler's List           8.5
# 6    1974-12-20                         The Godfather: Part II           8.5
# 7    2002-09-20                                  Spirited Away           8.5
# 8    1999-12-10                                 The Green Mile           8.5
# 9    1998-10-22                              Life Is Beautiful           8.5
# 10   1994-10-14                                   Pulp Fiction           8.4
# 11   2018-12-14              Spider-Man: Into the Spider-Verse           8.4
# 12   2008-07-18                                The Dark Knight           8.4
# 13   1994-07-06                                   Forrest Gump           8.4
# 14   1999-10-15                                     Fight Club           8.4
# 15   2003-12-17  The Lord of the Rings: The Return of the King           8.4
# 16   1960-09-08                                         Psycho           8.4
# 17   1963-09-11                                       Harakiri           8.4
# 18   1967-12-29                 The Good, the Bad and the Ugly           8.4
# 19   1957-04-10                                   12 Angry Men           8.4
# 0    1990-09-19                                     GoodFellas           8.4
# 1    1984-06-01                    Once Upon a Time in America           8.4
# 2    2002-06-14                                Cinema Paradiso           8.4
# 3    1975-11-18                One Flew Over the Cuckoo's Nest           8.4
# 4    1956-11-19                                  Seven Samurai           8.4
# 5    2000-09-15                                   A Dog's Will           8.4
# 6    1931-03-07                                    City Lights           8.4
# 7    2014-10-10                                       Whiplash           8.4
# 8    2019-01-01                         Grave of the Fireflies           8.4
# 9    2002-08-31                                    City of God           8.4
# ..          ...                                            ...           ...
# 10   1999-03-30                                     The Matrix           8.1
# 11   2016-11-04                                  Hacksaw Ridge           8.1
# 12   1963-05-07                                        Sanjuro           8.1
# 13   2007-12-28                            There Will Be Blood           8.1
# 14   1994-09-15                              Chungking Express           8.1
# 15   1947-04-11                               Monsieur Verdoux           8.1
# 16   2010-09-04                                      Incendies           8.1
# 17   2003-04-24                             Memories of Murder           8.1
# 18   2019-03-01                 The Boy Who Harnessed the Wind           8.1
# 19   2011-09-22                                       Silenced           8.1
# 0    1983-10-05                                      Nostalgia           8.1
# 1    1973-12-25                                      The Sting           8.1
# 2    2009-03-01                               Tel chi el telùn           8.1
# 3    2014-12-19                             The Imitation Game           8.1
# 4    2006-06-06                            The Lives of Others           8.1
# 5    1950-02-02                                  The Third Man           8.1
# 6    1979-05-25                                          Alien           8.1
# 7    2004-03-19          Eternal Sunshine of the Spotless Mind           8.1
# 8    1941-05-01                                   Citizen Kane           8.1
# 9    1957-12-31                              Nights of Cabiria           8.1
# 10   1958-12-28                            The Hidden Fortress           8.1
# 11   1980-10-03                               The Elephant Man           8.1
# 12   2015-08-28                              The Second Mother           8.1
# 13   2012-11-02                                       Paperman           8.1
# 14   2010-02-05                           Castaway on the Moon           8.1
# 15   1982-02-10                                       Das Boot           8.1
# 16   2018-11-02                              Bohemian Rhapsody           8.1
# 17   1955-02-16                              The Wages of Fear           8.1
# 18   1982-01-01                                        Vincent           8.1
# 19   1961-12-19                          Judgment at Nuremberg           8.0
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 19
# Data columns (total 5 columns):
# overview        200 non-null object
# popularity      200 non-null float64
# release_date    200 non-null object
# title           200 non-null object
# vote_average    200 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 9.4+ KB

# %%
df.shape
# Out:
# (200, 5)
